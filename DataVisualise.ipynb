# %%
import pandas as pd
import ruptures as rpt

# %%
fileVelo = 'C://python//train//fall_csv_new//video1.csv'
fileDiff = 'C://python//train//fall_csv_new_test//video1.csv'

# %%
df = pd.read_csv(fileVelo)

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.425817  0.000000  1.291612  0.000000  1.273600  0.000000  1.282606
# 1  1.423056  0.002760  1.289199  0.002413  1.267598  0.006002  1.278399
# 2  1.412025  0.006896  1.282935  0.004338  1.262305  0.005648  1.272620
# 3  1.424405  0.000471  1.284954  0.002219  1.264669  0.002977  1.274812
# 4  1.433229 -0.001853  1.287736  0.000969  1.275059 -0.000365  1.281397
#
#           7         8         9  ...        20        21        22        23  \
# 0  0.000000  1.067356  0.000000  ...  0.803519  0.000000  0.413940  0.000000
# 1  0.004207  1.071585 -0.004229  ...  0.803540 -0.000021  0.414624 -0.000684
# 2  0.004993  1.064302  0.001527  ...  0.803515  0.000002  0.415184 -0.000622
# 3  0.002598  1.072875 -0.001840  ...  0.803506  0.000004  0.414733 -0.000265
# 4  0.000302  1.071692 -0.001084  ...  0.803503  0.000004  0.421460 -0.001880
#
#          24        25        26        27        28        29
# 0  0.434163  0.000000  0.121884  0.000000  0.106779  0.000000
# 1  0.436208 -0.002045  0.129032 -0.007148  0.110013 -0.003234
# 2  0.424521  0.004821  0.139351 -0.008734  0.109438 -0.001330
# 3  0.423424  0.003580  0.130820 -0.002979  0.108801 -0.000674
# 4  0.430739  0.000856  0.153222 -0.007835  0.114790 -0.002003
#
# [5 rows x 30 columns]

# %%
dfVelo = df[df.columns[1::2]]

# %%
dfVelo.head(10)
# Out:
#           1         3         5         7         9        11        13  \
# 0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.002760  0.002413  0.006002  0.004207 -0.004229  0.000988 -0.009170
# 2  0.006896  0.004338  0.005648  0.004993  0.001527  0.003834  0.000080
# 3  0.000471  0.002219  0.002977  0.002598 -0.001840  0.001376 -0.004834
# 4 -0.001853  0.000969 -0.000365  0.000302 -0.001084 -0.002605 -0.003203
# 5 -0.001351  0.001281  0.001246  0.001263 -0.001302 -0.000522 -0.003683
# 6 -0.004192  0.000489 -0.000026  0.000232 -0.000273 -0.001278 -0.002572
# 7 -0.002641  0.000233  0.000373  0.000303 -0.000058 -0.000471 -0.002096
# 8 -0.001307  0.001824  0.001422  0.001623  0.001254  0.000992 -0.000592
# 9 -0.002503  0.000793  0.000371  0.000582  0.000036  0.000235 -0.002362
#
#          15            17        19            21        23        25  \
# 0  0.000000  0.000000e+00  0.000000  0.000000e+00  0.000000  0.000000
# 1 -0.002221  7.473000e-07 -0.000043 -2.090780e-05 -0.000684 -0.002045
# 2  0.001271 -6.194176e-04  0.000623  1.872800e-06 -0.000622  0.004821
# 3 -0.000065 -2.586704e-04  0.000267  4.269600e-06 -0.000265  0.003580
# 4 -0.004019 -4.666136e-04  0.000475  3.984200e-06 -0.001880  0.000856
# 5 -0.001014 -6.728928e-04  0.000665 -4.064700e-06  0.000186  0.002648
# 6 -0.002563 -1.310113e-04  0.000132  4.318000e-07  0.001101  0.001582
# 7 -0.001030 -5.815903e-04  0.000578 -1.955500e-06  0.000325  0.003732
# 8  0.000834 -6.562210e-05  0.000051 -7.425000e-06  0.001131  0.003038
# 9  0.000731 -2.722416e-04  0.000273  2.403000e-07  0.000239  0.002394
#
#          27        29
# 0  0.000000  0.000000
# 1 -0.007148 -0.003234
# 2 -0.008734 -0.001330
# 3 -0.002979 -0.000674
# 4 -0.007835 -0.002003
# 5  0.000464  0.003535
# 6  0.002502  0.001624
# 7 -0.001068 -0.000022
# 8  0.004466 -0.002027
# 9 -0.000179 -0.003562

# %%
dfVelo.plot(figsize=(20, 10), style='.-')
# Out:
# <AxesSubplot:>

# %%
dfPoint = df[df.columns[::2]]

# %%
dfPoint.plot(figsize=(20, 10), style='.-')
# Out:
# <AxesSubplot:>

# %%
df2 = pd.read_csv(fileDiff)

# %%
df2Diff = df2[df2.columns[1::2]]

# %%
df2Diff.plot(figsize=(20, 10), style='.-')
# Out:
# <AxesSubplot:>

# %%
df2Diff.tail()
# Out:
#             1         3         5         7         9        11        13  \
# 110  0.715156  0.508870  0.357470  0.433170  0.477323  0.292323  0.369262
# 111  0.801670  0.556596  0.496764  0.526680  0.517374  0.394478  0.541828
# 112  0.756254  0.694520  0.367709  0.531115  0.616422  0.153341  0.369728
# 113  1.001721  0.884903  0.808796  0.846850  0.805349  0.485395  0.771676
# 114  0.995671  0.831868  0.727920  0.779894  0.504696  0.406146  0.137987
#
#            15        17        19        21        23        25        27  \
# 110  0.275643  0.040988 -0.040868  0.000060 -0.309845 -0.412576 -0.619209
# 111  0.453610 -0.010037  0.007959 -0.001039 -0.190372 -0.163844 -0.412847
# 112  0.124674  0.079883 -0.078316  0.000783 -0.186827 -0.349067 -0.476205
# 113  0.257957 -0.019159  0.020498  0.000670 -0.706032 -0.628439 -1.224599
# 114  0.085008  0.043637 -0.042180  0.000728 -0.598716 -0.644690 -1.051951
#
#            29
# 110 -0.668106
# 111 -0.392603
# 112 -0.592198
# 113 -1.233748
# 114 -1.140496

# %%
df2Point = df2[df2.columns[::2]]

# %%
df2Point.plot(figsize=(20, 10), style='.-')
# Out:
# <AxesSubplot:>

# %%
algo1 = rpt.Pelt(model="rbf").fit(df2Diff.iloc[:,0].to_numpy())
change_location1 = algo1.predict(pen=10)

# %%
change_location1
# Out:
# [85, 115]
