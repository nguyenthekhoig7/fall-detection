# %%
import pandas as pd
import ruptures as rpt

# %%
fileVelo = 'C://python//train//fall_csv_new//video1.csv'
fileDiff = 'C://python//train//fall_csv_new_test//video1.csv'

# %%
df = pd.read_csv(fileVelo)

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.011877  0.000000  0.877672  0.000000  0.859660  0.000000  0.868666
# 1  1.009117 -0.002760  0.875259 -0.002413  0.853659 -0.006002  0.864459
# 2  0.998085 -0.006896  0.868995 -0.004338  0.848365 -0.005648  0.858680
# 3  1.010465 -0.000471  0.871015 -0.002219  0.850730 -0.002977  0.860872
# 4  1.019290  0.001853  0.873796 -0.000969  0.861119  0.000365  0.867458
#
#           7         8         9  ...        16            17        18  \
# 0  0.000000  0.653417  0.000000  ...  0.385973  0.000000e+00  0.393185
# 1 -0.004207  0.657646  0.004229  ...  0.385972 -7.473000e-07  0.393228
# 2 -0.004993  0.650363 -0.001527  ...  0.387212  6.194176e-04  0.391939
# 3 -0.002598  0.658936  0.001840  ...  0.386749  2.586704e-04  0.392384
# 4 -0.000302  0.657752  0.001084  ...  0.387839  4.666136e-04  0.391287
#
#          19        20        21        22        23        24        25
# ...

# %%
dfVelo = df[df.columns[1::2]]

# %%
dfVelo.head(10)
# Out:
#           1         3         5         7         9        11        13  \
# 0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1 -0.002760 -0.002413 -0.006002 -0.004207  0.004229 -0.000988  0.009170
# 2 -0.006896 -0.004338 -0.005648 -0.004993 -0.001527 -0.003834 -0.000080
# 3 -0.000471 -0.002219 -0.002977 -0.002598  0.001840 -0.001376  0.004834
# 4  0.001853 -0.000969  0.000365 -0.000302  0.001084  0.002605  0.003203
# 5  0.001351 -0.001281 -0.001246 -0.001263  0.001302  0.000522  0.003683
# 6  0.004192 -0.000489  0.000026 -0.000232  0.000273  0.001278  0.002572
# 7  0.002641 -0.000233 -0.000373 -0.000303  0.000058  0.000471  0.002096
# 8  0.001307 -0.001824 -0.001422 -0.001623 -0.001254 -0.000992  0.000592
# 9  0.002503 -0.000793 -0.000371 -0.000582 -0.000036 -0.000235  0.002362
#
#          15            17        19            21        23        25
# 0  0.000000  0.000000e+00  0.000000  0.000000e+00  0.000000  0.000000
# ...

# %%
dfVelo.plot(figsize=(20, 10), style='.-')
# Out:
# <AxesSubplot:>

# %%
dfPoint = df[df.columns[::2]]

# %%
dfPoint.plot(figsize=(20, 10), style='.-')
# Out:
# <AxesSubplot:>

# %%
df2 = pd.read_csv(fileDiff)

# %%
df2Diff = df2[df2.columns[1::2]]

# %%
df2Diff.plot(figsize=(20, 10), style='.-')
# Out:
# <AxesSubplot:>

# %%
df2Diff.tail()
# Out:
#             1         3         5         7         9        11        13  \
# 110  0.715156  0.508870  0.357470  0.433170  0.477323  0.292323  0.369262
# 111  0.801670  0.556596  0.496764  0.526680  0.517374  0.394478  0.322369
# 112  0.756254  0.694520  0.367709  0.531115  0.616422  0.153341  0.369728
# 113  1.001721  0.870441  0.808796  0.846850  0.501485  0.485395  0.092521
# 114  0.995671  0.831868  0.727920  0.779894  0.504696  0.406146  0.137987
#
#            15        17        19        21        23        25
# 110  0.275643  0.040988 -0.040868  0.000060 -0.309845 -0.412576
# 111  0.348203 -0.010037  0.007959 -0.001039 -0.190372 -0.163844
# 112  0.124674  0.079883 -0.078316  0.000783 -0.186827 -0.349067
# 113  0.257957 -0.019159  0.020498  0.000670 -0.706032 -0.628439
# 114  0.085008  0.043637 -0.042180  0.000728 -0.598716 -0.644690

# %%
df2Point = df2[df2.columns[::2]]

# %%
df2Point.plot(figsize=(20, 10), style='.-')
# Out:
# <AxesSubplot:>

# %%
algo1 = rpt.Pelt(model="rbf").fit(df2Diff.iloc[:,0].to_numpy())
change_location1 = algo1.predict(pen=10)

# %%
change_location1
# Out:
# [85, 115]
